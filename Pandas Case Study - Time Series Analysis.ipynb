# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# till now
# Timestamp
print(pd.DatetimeIndex([pd.Timestamp('6th jan 2023 8:10'), 
                  pd.Timestamp('7th jan 2023 8:10'),
                  pd.Timestamp('8th jan 2023 8:10')]).year)

# DatetimeIndex -> df and series index
print(pd.DatetimeIndex([pd.Timestamp('6th jan 2023 8:10'), 
                  pd.Timestamp('7th jan 2023 8:10'),
                  pd.Timestamp('8th jan 2023 8:10')]))
# date_range()
print(pd.date_range(start='2023-1-6', end='2023-1-31', freq='D'))

#to_datetime
s = pd.Series(['2023/1/6','2023/1/7','2023/1/8'])
print(s)
print(pd.to_datetime(s).dt.day)
# Out:
# Int64Index([2023, 2023, 2023], dtype='int64')
# DatetimeIndex(['2023-01-06 08:10:00', '2023-01-07 08:10:00',
#                '2023-01-08 08:10:00'],
#               dtype='datetime64[ns]', freq=None)
# DatetimeIndex(['2023-01-06', '2023-01-07', '2023-01-08', '2023-01-09',
#                '2023-01-10', '2023-01-11', '2023-01-12', '2023-01-13',
#                '2023-01-14', '2023-01-15', '2023-01-16', '2023-01-17',
#                '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-21',
#                '2023-01-22', '2023-01-23', '2023-01-24', '2023-01-25',
#                '2023-01-26', '2023-01-27', '2023-01-28', '2023-01-29',
#                '2023-01-30', '2023-01-31'],
#               dtype='datetime64[ns]', freq='D')
# 0    2023/1/6
# 1    2023/1/7
# 2    2023/1/8
# dtype: object
# 0    6
# 1    7
# 2    8
# dtype: int64

# %% [markdown]
# # TimeDelta Object
# Represents a duration, the difference between two dates or times.

# %%
# Create using Timestamp obj
t1 = pd.Timestamp('6th jan 2023 8:20:14')
t2 = pd.Timestamp('26th jan 2023 10:00:00')
t1-t2
# Out:
# Timedelta('-21 days +22:20:14')

# %%
#Standalone Creation
pd.Timedelta(days = 2, hours=10, minutes=35, seconds=40)
# Out:
# Timedelta('2 days 10:35:40')

# %%
#Arithmetic
pd.Timestamp('6th jan 2023') + pd.Timedelta(days = 2, hours=10, minutes=35, seconds=40)
# Out:
# Timestamp('2023-01-08 10:35:40')

# %%
pd.date_range(start='2023-1-6', end = '2023-1-31', freq='D') + pd.Timedelta(days = 2, hours=10, minutes=35, seconds=40)
# Out:
# DatetimeIndex(['2023-01-08 10:35:40', '2023-01-09 10:35:40',
#                '2023-01-10 10:35:40', '2023-01-11 10:35:40',
#                '2023-01-12 10:35:40', '2023-01-13 10:35:40',
#                '2023-01-14 10:35:40', '2023-01-15 10:35:40',
#                '2023-01-16 10:35:40', '2023-01-17 10:35:40',
#                '2023-01-18 10:35:40', '2023-01-19 10:35:40',
#                '2023-01-20 10:35:40', '2023-01-21 10:35:40',
#                '2023-01-22 10:35:40', '2023-01-23 10:35:40',
#                '2023-01-24 10:35:40', '2023-01-25 10:35:40',
#                '2023-01-26 10:35:40', '2023-01-27 10:35:40',
#                '2023-01-28 10:35:40', '2023-01-29 10:35:40',
#                '2023-01-30 10:35:40', '2023-01-31 10:35:40',
#                '2023-02-01 10:35:40', '2023-02-02 10:35:40'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2023-1-6', end = '2023-1-31', freq='D') - pd.Timedelta(days = 2, hours=10, minutes=35, seconds=40)
# Out:
# DatetimeIndex(['2023-01-03 13:24:20', '2023-01-04 13:24:20',
#                '2023-01-05 13:24:20', '2023-01-06 13:24:20',
#                '2023-01-07 13:24:20', '2023-01-08 13:24:20',
#                '2023-01-09 13:24:20', '2023-01-10 13:24:20',
#                '2023-01-11 13:24:20', '2023-01-12 13:24:20',
#                '2023-01-13 13:24:20', '2023-01-14 13:24:20',
#                '2023-01-15 13:24:20', '2023-01-16 13:24:20',
#                '2023-01-17 13:24:20', '2023-01-18 13:24:20',
#                '2023-01-19 13:24:20', '2023-01-20 13:24:20',
#                '2023-01-21 13:24:20', '2023-01-22 13:24:20',
#                '2023-01-23 13:24:20', '2023-01-24 13:24:20',
#                '2023-01-25 13:24:20', '2023-01-26 13:24:20',
#                '2023-01-27 13:24:20', '2023-01-28 13:24:20'],
#               dtype='datetime64[ns]', freq='D')

# %%
# real life eg
df = pd.read_csv('datasets/deliveries.csv')
df.head()
# Out:
#   order_date delivery_date
# 0    5/24/98        2/5/99
# 1    4/22/92        3/6/98
# 2    2/10/91       8/26/92
# 3    7/21/92      11/20/97
# 4     9/2/93       6/10/98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    object
#  1   delivery_date  501 non-null    object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['delivery_date'] = pd.to_datetime(df['delivery_date'])

# %%
df['delivery_time_period'] = df['delivery_date'] - df['order_date']

# %%
df.head()
# Out:
#   order_date delivery_date delivery_time_period
# 0 1998-05-24    1999-02-05             257 days
# 1 1992-04-22    1998-03-06            2144 days
# 2 1991-02-10    1992-08-26             563 days
# 3 1992-07-21    1997-11-20            1948 days
# 4 1993-09-02    1998-06-10            1742 days

# %%
df['delivery_time_period'].mean()
# Out:
# Timedelta('1217 days 22:53:53.532934128')

# %% [markdown]
# # Time series
# A time series is a data set that tracks a sample over time. In particular, a time series allows one to see what factors influence certain variables from period to period. Time series analysis can be useful to see how a given asset, security, or economic variable changes over time.
#
# Examples
#
# - Financial Data (Company stocks)
# - Natural Data (Rainfall measurement)
# - Event Data (Covid)
# - Medical Data (Heart rate monitoring)
#
# Types of Operations done on Time Series
#
# - Time Series Analysis
# - Time Series Forecasting

# %%
google = pd.read_csv('datasets/google.csv')
google.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
google.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close   Volume
# 4466  2295.850098  1164100
# 4467  2334.030029  1078800
# 4468  2248.020020  1399100
# 4469  2214.909912  1459600
# 4470  2186.260010  1878100

# %%
google['Date'] = pd.to_datetime(google['Date'])
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   datetime64[ns]
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 244.6 KB

# %%
google.set_index('Date', inplace=True)

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
# fetch a specific date
google.loc['2022-05-20']
# Out:
# Open         2.241710e+03
# High         2.251000e+03
# Low          2.127460e+03
# Close        2.186260e+03
# Adj Close    2.186260e+03
# Volume       1.878100e+06
# Name: 2022-05-20 00:00:00, dtype: float64

# %%
# partial indexing -> select a year/month
google.loc['2022-4']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-04-01  2800.199951  2819.000000  2775.939941  2814.000000  2814.000000
# 2022-04-04  2816.489990  2880.875000  2816.489990  2872.850098  2872.850098
# 2022-04-05  2867.989990  2871.800049  2818.870117  2821.260010  2821.260010
# 2022-04-06  2783.229980  2796.969971  2728.362061  2743.520020  2743.520020
# 2022-04-07  2732.360107  2754.030029  2697.145020  2729.300049  2729.300049
# 2022-04-08  2725.000000  2725.000000  2675.050049  2680.209961  2680.209961
# 2022-04-11  2658.000000  2658.783936  2592.350098  2595.929932  2595.929932
# 2022-04-12  2648.469971  2648.469971  2551.520020  2567.489990  2567.489990
# 2022-04-13  2572.530029  2613.114990  2568.771973  2605.719971  2605.719971
# 2022-04-14  2612.989990  2614.205078  2542.229980  2545.060059  2545.060059
# 2022-04-18  2548.199951  2574.239990  2531.569092  2559.219971  2559.219971
# ...

# %%
# Create year, month name, day
google['Month_Name'] = google.index.month_name()
google['Weekday_Name'] = google.index.day_name()
google['Quarter'] = google.index.quarter

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276
#
#            Month_Name Weekday_Name  Quarter
# Date
# 2004-08-19     August     Thursday        3
# 2004-08-20     August       Friday        3
# 2004-08-23     August       Monday        3
# 2004-08-24     August      Tuesday        3
# 2004-08-25     August    Wednesday        3

# %%
# slicing

google.loc['2020-12-15':'2022-1-5']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-12-15  1764.420044  1771.420044  1749.949951  1767.770020  1767.770020
# 2020-12-16  1772.880005  1773.000000  1756.079956  1763.000000  1763.000000
# 2020-12-17  1768.510010  1771.784058  1738.660034  1747.900024  1747.900024
# 2020-12-18  1754.180054  1755.109985  1720.219971  1731.010010  1731.010010
# 2020-12-21  1713.510010  1740.849976  1699.000000  1739.369995  1739.369995
# ...                 ...          ...          ...          ...          ...
# 2021-12-30  2929.000000  2941.250000  2915.169922  2920.050049  2920.050049
# 2021-12-31  2910.879883  2927.300049  2893.550049  2893.590088  2893.590088
# 2022-01-03  2889.510010  2911.000000  2870.050049  2901.489990  2901.489990
# 2022-01-04  2911.010010  2932.199951  2876.322998  2888.330078  2888.330078
# 2022-01-05  2883.620117  2885.959961  2750.469971  2753.070068  2753.070068
#
# ...

# %%
# challenge -> fetch into for a particular date every year -> limitation of timedelta
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276
#
#            Month_Name Weekday_Name  Quarter
# Date
# 2004-08-19     August     Thursday        3
# 2004-08-20     August       Friday        3
# 2004-08-23     August       Monday        3
# 2004-08-24     August      Tuesday        3
# 2004-08-25     August    Wednesday        3

# %%
pd.date_range(start = '2005-1-6', end = '2022-1-6', 
              freq=pd.DateOffset(years=1))
# Out:
# DatetimeIndex(['2005-01-06', '2006-01-06', '2007-01-06', '2008-01-06',
#                '2009-01-06', '2010-01-06', '2011-01-06', '2012-01-06',
#                '2013-01-06', '2014-01-06', '2015-01-06', '2016-01-06',
#                '2017-01-06', '2018-01-06', '2019-01-06', '2020-01-06',
#                '2021-01-06', '2022-01-06'],
#               dtype='datetime64[ns]', freq='<DateOffset: years=1>')

# %%
google[google.index.isin(pd.date_range(start = '2005-1-6', end = '2022-1-6', 
              freq=pd.DateOffset(years=1)))]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2005-01-06    97.175758    97.584229    93.509506    93.922951    93.922951
# 2006-01-06   227.581970   234.371521   225.773743   231.960556   231.960556
# 2009-01-06   165.868286   169.763687   162.585587   166.406265   166.406265
# 2010-01-06   311.761444   311.761444   302.047852   302.994293   302.994293
# 2011-01-06   304.199799   308.060303   303.885956   305.604523   305.604523
# 2012-01-06   328.344299   328.767700   323.681763   323.796326   323.796326
# 2014-01-06   554.426880   557.340942   551.154114   556.573853   556.573853
# 2015-01-06   513.589966   514.761719   499.678131   500.585632   500.585632
# 2016-01-06   730.000000   747.179993   728.919983   743.619995   743.619995
# 2017-01-06   795.260010   807.900024   792.203979   806.150024   806.150024
# 2020-01-06  1350.000000  1396.500000  1350.000000  1394.209961  1394.209961
# ...

# %%
# plotting via a single col
google['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# plotting via all cols together
subset_google = google[['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close']]
ax = subset_google.plot(subplots=True,
            layout=(3,2),
            sharex=False,
            sharey=False,
            linewidth=0.7,
            fontsize=10,
            legend=False,
            figsize=(20,15),
            title=['Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'])

# %%
# plot for particular year , month
# yearly
google.loc['2021']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# monthly
google.loc['2021-12']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
google['Close'].asfreq('Q', method='ffill').plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# monthly trend
google.groupby('Month_Name')['Close'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Month_Name'>

# %%
# daily trend
google.groupby('Weekday_Name')['Close'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Weekday_Name'>

# %%
# quarterly trend
google.groupby('Quarter')['Close'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Quarter'>

# %%
# frequency
google.index
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-23', '2004-08-24',
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-16', '2022-05-17', '2022-05-18',
#                '2022-05-19', '2022-05-20'],
#               dtype='datetime64[ns]', name='Date', length=4471, freq=None)

# %%
google.asfreq('B')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
# ...

# %%
google.index
# Out:
# DatetimeIndex(['2004-08-19', '2004-08-20', '2004-08-23', '2004-08-24',
#                '2004-08-25', '2004-08-26', '2004-08-27', '2004-08-30',
#                '2004-08-31', '2004-09-01',
#                ...
#                '2022-05-09', '2022-05-10', '2022-05-11', '2022-05-12',
#                '2022-05-13', '2022-05-16', '2022-05-17', '2022-05-18',
#                '2022-05-19', '2022-05-20'],
#               dtype='datetime64[ns]', name='Date', length=4471, freq=None)

# %%
# quarterly
google.asfreq('Q')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-09-30    64.707458    65.902977    64.259140    64.558022    64.558022
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# 2005-03-31    88.642746    90.356323    88.488327    89.917969    89.917969
# 2005-06-30   146.620438   148.906860   144.976593   146.525787   146.525787
# 2005-09-30   156.523315   158.157181   155.561920   157.639130   157.639130
# ...                 ...          ...          ...          ...          ...
# 2021-03-31  2059.120117  2093.326904  2056.745117  2068.629883  2068.629883
# 2021-06-30  2513.071045  2516.000000  2495.149902  2506.320068  2506.320068
# 2021-09-30  2686.500000  2711.800049  2660.000000  2665.310059  2665.310059
# 2021-12-31  2910.879883  2927.300049  2893.550049  2893.590088  2893.590088
# 2022-03-31  2848.969971  2852.889893  2792.379883  2792.989990  2792.989990
#
# ...

# %%
# Yearly
google.asfreq('Y')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-12-31    99.243011    99.566795    95.920464    96.035034    96.035034
# 2005-12-31          NaN          NaN          NaN          NaN          NaN
# 2006-12-31          NaN          NaN          NaN          NaN          NaN
# 2007-12-31   347.980682   349.933350   344.000610   344.448914   344.448914
# 2008-12-31   151.532028   154.919327   150.739990   153.250580   153.250580
# 2009-12-31   311.208527   311.532288   308.832428   308.832428   308.832428
# 2010-12-31   297.255798   298.092682   294.909607   295.875977   295.875977
# 2011-12-31          NaN          NaN          NaN          NaN          NaN
# 2012-12-31   348.693024   353.958282   346.700470   352.369232   352.369232
# 2013-12-31   554.043335   558.406982   551.064453   558.262512   558.262512
# 2014-12-31   529.795471   531.141724   524.360352   524.958740   524.958740
# ...

# %%
# Hourly
google.asfreq('6H', method = 'ffill')
# Out:
#                             Open         High          Low        Close  \
# Date
# 2004-08-19 00:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 06:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 12:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-19 18:00:00    49.813290    51.835709    47.800831    49.982655
# 2004-08-20 00:00:00    50.316402    54.336334    50.062355    53.952770
# ...                          ...          ...          ...          ...
# 2022-05-19 00:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 06:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 12:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-19 18:00:00  2236.820068  2271.750000  2209.360107  2214.909912
# 2022-05-20 00:00:00  2241.709961  2251.000000  2127.459961  2186.260010
#
#                        Adj Close    Volume Month_Name Weekday_Name  Quarter
# Date
# ...

# %% [markdown]
# # Resampling
# Resampling involves changing the frequency of your time series observations.
#
# Two types of resampling are:
#
# Upsampling: Where you increase the frequency of the samples, such as from minutes to seconds.
#
# Downsampling: Where you decrease the frequency of the samples, such as from days to months.

# %%
# Downsampling
google['Close'].plot()
google['Close'].resample('Q').mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Upsampling
google['Close'].resample('12H').interpolate(method='spline', order=2).plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Rolling Window(Smoothing)
# Time series data in original format can be quite volatile, especially on smaller aggregation levels. The concept of rolling, or moving averages is a useful technique for smoothing time series data.

# %%
print(google['Close'].rolling(3).mean())
print(google['Close'])
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20            NaN
# 2004-08-23      52.810387
# 2004-08-24      53.562567
# 2004-08-25      53.179006
#                  ...
# 2022-05-16    2296.460043
# 2022-05-17    2320.063395
# 2022-05-18    2292.633382
# 2022-05-19    2265.653320
# 2022-05-20    2216.396647
# Name: Close, Length: 4471, dtype: float64
# Date
# 2004-08-19      49.982655
# 2004-08-20      53.952770
# 2004-08-23      54.495735
# 2004-08-24      52.239197
# 2004-08-25      52.802086
#                  ...
# 2022-05-16    2295.850098
# 2022-05-17    2334.030029
# 2022-05-18    2248.020020
# 2022-05-19    2214.909912
# 2022-05-20    2186.260010
# Name: Close, Length: 4471, dtype: float64

# %%
google['Close'].plot()
google['Close'].rolling(7).mean().plot() #30  = 30 days
# Out:
# <Axes: xlabel='Date'>

# %%
google['Close'].plot()
google['Close'].ewm(7).mean().plot() # ewm = exponential moving average
# Out:
# <Axes: xlabel='Date'>

# %%
google['Close'].plot()
google['Close'].rolling(7).mean().plot()
google['Close'].ewm(7).mean().plot()
# Out:
# <Axes: title={'center': 'Rolling'}, xlabel='Date'>

# %% [markdown]
# # Shifting
# The shift() function is Pandas is used to, well, shift the entire series up or down by the desired number of periods.

# %%
google['Close']
# Out:
# Date
# 2004-08-19      49.982655
# 2004-08-20      53.952770
# 2004-08-23      54.495735
# 2004-08-24      52.239197
# 2004-08-25      52.802086
#                  ...
# 2022-05-16    2295.850098
# 2022-05-17    2334.030029
# 2022-05-18    2248.020020
# 2022-05-19    2214.909912
# 2022-05-20    2186.260010
# Name: Close, Length: 4471, dtype: float64

# %%
google['Close'].shift(1)
# Out:
# Date
# 2004-08-19            NaN
# 2004-08-20      49.982655
# 2004-08-23      53.952770
# 2004-08-24      54.495735
# 2004-08-25      52.239197
#                  ...
# 2022-05-16    2330.310059
# 2022-05-17    2295.850098
# 2022-05-18    2334.030029
# 2022-05-19    2248.020020
# 2022-05-20    2214.909912
# Name: Close, Length: 4471, dtype: float64

# %%
#Use
login = pd.read_csv('datasets/login.csv', header=None)
df = login[[1,2]]
df.rename(columns={
    1: 'User_id',
    2: 'Login_Time'
}, inplace=True)
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_13600\3067834190.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.head()
# Out:
#    User_id           Login_Time
# 0      466  2017-01-07 18:24:07
# 1      466  2017-01-07 18:24:55
# 2      458  2017-01-07 18:25:18
# 3      458  2017-01-07 18:26:21
# 4      592  2017-01-07 19:09:59

# %%
user_df = df[df['User_id'] == 413]
user_df.head()
# Out:
#     User_id           Login_Time
# 11      413  2017-01-09 12:29:25
# 12      413  2017-01-09 12:40:39
# 14      413  2017-01-09 14:08:04
# 33      413  2017-01-10 14:36:23
# 35      413  2017-01-10 15:22:45

# %%
user_df['Login_Time'] = pd.to_datetime(user_df['Login_Time'])
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_13600\2390359809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_df['Login_Time'] = pd.to_datetime(user_df['Login_Time'])

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 11 to 2997
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   User_id     222 non-null    int64
#  1   Login_Time  222 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 5.2 KB

# %%
user_df['Shifted']  = user_df['Login_Time'].shift(1)
# Out:
# C:\Users\Rudra\AppData\Local\Temp\ipykernel_13600\1452210730.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_df['Shifted']  = user_df['Login_Time'].shift(1)

# %%
user_df
# Out:
#       User_id          Login_Time             Shifted
# 11        413 2017-01-09 12:29:25                 NaT
# 12        413 2017-01-09 12:40:39 2017-01-09 12:29:25
# 14        413 2017-01-09 14:08:04 2017-01-09 12:40:39
# 33        413 2017-01-10 14:36:23 2017-01-09 14:08:04
# 35        413 2017-01-10 15:22:45 2017-01-10 14:36:23
# ...       ...                 ...                 ...
# 2958      413 2017-12-29 18:20:32 2017-12-29 18:19:48
# 2963      413 2017-12-30 13:41:21 2017-12-29 18:20:32
# 2974      413 2018-01-01 15:16:25 2017-12-30 13:41:21
# 2982      413 2018-01-02 18:15:45 2018-01-01 15:16:25
# 2997      413 2018-01-04 10:43:43 2018-01-02 18:15:45
#
# [222 rows x 3 columns]

# %%
(user_df['Login_Time'] - user_df['Shifted']).mean()
# Out:
# Timedelta('1 days 15:05:13.384615384')
